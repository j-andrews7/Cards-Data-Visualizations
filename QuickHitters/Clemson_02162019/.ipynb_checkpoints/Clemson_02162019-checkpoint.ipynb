# %%
library("ncaahoopR")
# Out:
# Registering font with R using pdfFonts(): DejaVu Math TeX Gyre
# Registering font with R using pdfFonts(): DejaVu Sans
# Registering font with R using pdfFonts(): DejaVu Sans Light
# Registering font with R using pdfFonts(): DejaVu Sans Condensed
# Registering font with R using pdfFonts(): DejaVu Sans Mono
# Registering font with R using pdfFonts(): DejaVu Serif
# Registering font with R using pdfFonts(): DejaVu Serif Condensed
# Registering font with R using pdfFonts(): Liberation Mono
# Registering font with R using pdfFonts(): Liberation Sans
# Registering font with R using pdfFonts(): Liberation Sans Narrow
# Registering font with R using pdfFonts(): Liberation Serif

# %%
louisville = ncaa_colors[ncaa_colors$ncaa_name == "Louisville",]
clemson = ncaa_colors[ncaa_colors$ncaa_name == "Clemson",]

# %%
pdf("WinPro_Gameflow.pdf")
gg_wp_chart(401082663, louisville$primary_color, clemson$primary_color, show_labels = T)
game_flow(401082663, louisville$primary_color, clemson$primary_color)
dev.off()
# Out:
# Error in pdf("WinPro_Gameflow_Assists.pdf", family = "Arial Black"): unknown family 'Arial Black'
# Traceback:
#
# 1. pdf("WinPro_Gameflow_Assists.pdf", family = "Arial Black")
# 2. stop(gettextf("unknown family '%s'", family), domain = NA)

# %%
assist_net("Louisville", 401082663, louisville$primary_color, message = "Assist Network - Louisville v Clemson 02/16/2019")
circle_assist_net("Louisville", 401082663, message = "Assist Network - Louisville v Clemson 02/16/2019")
circle_assist_net("Louisville", 401082663, message = "Assist Network - Louisville v Clemson 02/16/2019", highlight_player = "Christen Cunningham", highlight_color = "#FDBB30")
# Out:
# Scraping Data for Game: 1 of 1
# $clust_coeff
# [1] 0.231
#
# $page_ranks
#       Dwayne Sutton        Darius Perry      Malik Williams        Jordan Nwora
#           0.1644719           0.1540726           0.1507586           0.1507586
#        Ryan McMahon        Steven Enoch Christen Cunningham
#           0.1335027           0.1335027           0.1129328
#
# $hub_scores
# Christen Cunningham        Ryan McMahon        Darius Perry        Steven Enoch
#          0.99629608          0.08598908          0.00000000          0.00000000
#       Dwayne Sutton      Malik Williams        Jordan Nwora
#          0.00000000          0.00000000          0.00000000
#
# $auth_scores
#        Darius Perry        Ryan McMahon        Steven Enoch       Dwayne Sutton
#          0.78259483          0.39129742          0.39129742          0.28337987
#      Malik Williams        Jordan Nwora Christen Cunningham
#          0.02251493          0.02251493          0.00000000
#
# $ast_freq
# ...
